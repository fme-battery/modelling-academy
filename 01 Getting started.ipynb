# %% [markdown]
# ## Lesson 0: Getting started
#
# This tutorial relies on you being able to run some simple python routines. You don't have to be a very good programmer to follow this tutorial, and do not be afraid
# to ask for help from the instructors or your fellow students. We will use `jupyter`notebooks and run the code on a dedicated `jupyterhub`. The intention is that all
# the needed libraries are already installed so you don't have to strugle with that. However, there are sometimes discrepancies between intentions and the real life...

# %% [markdown]
# ### Lesson 0.1 Get access to the hub
#
# You will need a user on the FME Battery Modelling Academy Hub.
#
# 1. We will provide (or have provided) you with a link and a user name. Press that link...
# 2. Log in with your provided user name. The password you use the first time will be your permanent password. Remember it.
# 3. Open this notebook.

# %% [markdown]
# ### Lesson 0.2 and 0.3
#
# Run the cells below...
#
# Hint! try pressing Ctrl+Enter or Shift+Enter when the cursor is inside the cell

# %%
import pathlib
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("Excellent - python works!!")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
print(f"python version: {sys.version}")

# %%
import cellpy

print("Amazing - cellpy also seems to work")
print(f"cellpy version: {cellpy.__version__}")

# %%
filedir = pathlib.Path("cellpy-tutorial") / "data" / "raw"
assert filedir.is_dir()
print("You have access to the data folder :-)")
# single filename
filename = "20210210_FC_01_cc_01.res"
# list of files (continuations within same experiment)
filenamelist = [
    "20210210_FC_01_cc_01.res",
    "20210210_FC_01_cc_02.res",
    "20210210_FC_01_cc_03.res",
    "20210210_FC_01_cc_04.res",
]

filepaths = [filedir / file for file in filenamelist]
for filepath in filepaths:
    print(f"  filepath: {filepath} - {filepath.exists()}")
print("And there is some date there :-)")

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 1000)
y = np.sin(x) * x**2

fig, ax = plt.subplots()
ax.plot(x, y, "-.", label="my nice function")
ax.set_xlabel("x-value")
ax.set_xlim(-6.0, 6.0)
ax.set_ylabel("y-value")
ax.legend(frameon=False)
print("What a nice plot:")

# %% [markdown]
# ## Assigments
#
# ### A.0.1
#
# - Recreate the plot above with a red solid line instead of the "-."
# - Change the axis labels to something cool
# - Change the size of the figure

# %%
# Insert your code into this cell
