# %% [markdown]
# # Welcome to etc.
#
# Some stuff about the tutorial

# %% [markdown]
# ## Helpful links
#
#
#
# [https://cellpy.readthedocs.io/en/latest/](https://cellpy.readthedocs.io/en/latest/)
#
# [cellpy at github](https://github.com/jepegit/cellpy)
#
# [modelling academy repo](https://github.com/fme-battery/modelling-academy)
#
# etc

# %% [markdown]
# ## Initial test

# %%
import cellpy
cellpy.__version__
