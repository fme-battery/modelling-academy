# %% [markdown]
# # Some final remarks and call to action
#
# - Handling of battery data is complex
#
#     - Many formats
#     - Metadata
#     - What are the best practises?
#
# - Efficient tooling depends on either costly commercial solutions or tools open-sourced and driven by a few people, mainly on their free-time.
#
# - You want to help and contribute to open source, but
#     - contributing is very difficult - code-bases are usually not design by computer scientists
#     - example: `cellpy`

# %% [markdown]
# ![title](static/Screenshot-GitHub-cellpy.png)

# %% [markdown]
# ## Something is happening
#
# - Initiatives on EU and US level on standardizations
# - "Local" initiatives on lifting the quality of open-source tools
#
#     - SPEED: making `cellpy` shine.

# %% [markdown]
# ![title](static/SPEED.png)

# %% [markdown]
# - We can organize workshops, hackatons etc.
# - We (and you?) can start rewriting/restructuring the code to make it more accessible
#     - you can come with input
# - You can contribute, and we can help you getting started
#     - code
#     - other
